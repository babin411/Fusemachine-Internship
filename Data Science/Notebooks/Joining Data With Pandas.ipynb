# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\Babin\\Internship\\Data Science\\Notebooks'

# %%
os.chdir('..')
ward_path = os.path.join(os.getcwd(),'Datasets\\wards.csv')
ward_path
# Out:
# 'D:\\Babin\\Internship\\Data Science\\Datasets\\wards.csv'

# %%
census_path = os.path.join(os.getcwd(),'Datasets\\census.csv')
census_path
# Out:
# 'D:\\Babin\\Internship\\Data Science\\Datasets\\census.csv'

# %%
wards = pd.read_csv(ward_path)
wards.drop(columns='Unnamed: 0', axis=1,inplace = True)

# %%
wards
# Out:
#      ward                        alderman  \
# 0       1          "Proco ""Joe"" Moreno"
# 1       2                   Brian Hopkins
# 2       3                      Pat Dowell
# 3       4                William D. Burns
# 4       5              Leslie A. Hairston
# 5       6              Roderick T. Sawyer
# 6       7             Gregory I. Mitchell
# 7       8              Michelle A. Harris
# 8       9                Anthony A. Beale
# 9      10           Susan Sadlowski Garza
# 10     11          Patrick Daley Thompson
# 11     12                 George Cardenas
# 12     13                     Marty Quinn
# 13     14                 Edward M. Burke
# 14     15                Raymond A. Lopez
# 15     16                 Toni L. Foulkes
# 16     17                  David H. Moore
# 17     18               Derrick G. Curtis
# 18     19               Matthew J. O'Shea
# 19     20               Willie B. Cochran
# 20     21       "Howard B. Brookins  Jr."
# ...

# %%
census = pd.read_csv(census_path)
census.drop('Unnamed: 0', axis=1,inplace=True)

# %%
census
# Out:
#      ward   pop_2000   pop_2010  change  \
# 0       1      52951      56149      6%
# 1       2      54361      55805      3%
# 2       3      40385      53039     31%
# 3       4      51953      54589      5%
# 4       5      55302      51455     -7%
# 5       6      54989      52341     -5%
# 6       7      54593      51581     -6%
# 7       8      54039      51687     -4%
# 8       9      52008      51519     -1%
# 9      10      56613      51535     -9%
# 10     11      64228      51497    -20%
# 11     12      68922      52235    -24%
# 12     13      64382      53722    -17%
# 13     14      80143      54031    -33%
# 14     15      56057      51501     -8%
# 15     16      50205      51954      3%
# 16     17      49264      51846      5%
# 17     18      55043      52992     -4%
# 18     19      54546      51525     -6%
# 19     20      51854      52372      1%
# 20     21      51751      51632      0%
# 21     22      59734      53515    -10%
# ...

# %% [markdown]
# ### Ward Data

# %%
wards.head()
# Out:
#     ward                 alderman                            address    zip
# 0      1   "Proco ""Joe"" Moreno"          2058 NORTH WESTERN AVENUE  60647
# 1      2            Brian Hopkins         1400 NORTH  ASHLAND AVENUE  60622
# 2      3               Pat Dowell            5046 SOUTH STATE STREET  60609
# 3      4         William D. Burns   "435 EAST 35TH STREET 1ST FLOOR"  60616
# 4      5       Leslie A. Hairston              2325 EAST 71ST STREET  60649

# %%
wards.shape
# Out:
# (50, 4)

# %%
wards.columns = ['ward', 'alderman', 'address', 'zip']

# %% [markdown]
# ### Census Data

# %%
census.head()
# Out:
#     ward   pop_2000   pop_2010  change  \
# 0      1      52951      56149      6%
# 1      2      54361      55805      3%
# 2      3      40385      53039     31%
# 3      4      51953      54589      5%
# 4      5      55302      51455     -7%
#
#                                     address    zip
# 0               2765 WEST SAINT MARY STREET  60647
# 1                  WM WASTE MANAGEMENT 1500  60622
# 2                       17 EAST 38TH STREET  60653
# 3   31ST ST HARBOR BUILDING LAKEFRONT TRAIL  60653
# 4   JACKSON PARK LAGOON SOUTH CORNELL DRIVE  60637

# %%
census.shape
# Out:
# (50, 6)

# %%
census.columns = ['ward', 'pop_2000', 'pop_2010', 'change', 'address', 'zip']

# %% [markdown]
# ## Merging Tables

# %% [markdown]
# ### Inner Join

# %% [markdown]
# #### One to One Example

# %%
ward_census = wards.merge(census, on='ward')
ward_census.head()
# Out:
#    ward                 alderman                          address_x  zip_x  \
# 0     1   "Proco ""Joe"" Moreno"          2058 NORTH WESTERN AVENUE  60647
# 1     2            Brian Hopkins         1400 NORTH  ASHLAND AVENUE  60622
# 2     3               Pat Dowell            5046 SOUTH STATE STREET  60609
# 3     4         William D. Burns   "435 EAST 35TH STREET 1ST FLOOR"  60616
# 4     5       Leslie A. Hairston              2325 EAST 71ST STREET  60649
#
#    pop_2000  pop_2010 change                                 address_y  zip_y
# 0     52951     56149     6%               2765 WEST SAINT MARY STREET  60647
# 1     54361     55805     3%                  WM WASTE MANAGEMENT 1500  60622
# 2     40385     53039    31%                       17 EAST 38TH STREET  60653
# 3     51953     54589     5%   31ST ST HARBOR BUILDING LAKEFRONT TRAIL  60653
# 4     55302     51455    -7%   JACKSON PARK LAGOON SOUTH CORNELL DRIVE  60637

# %%
ward_census.columns
# Out:
# Index(['ward', 'alderman', 'address_x', 'zip_x', 'pop_2000', 'pop_2010',
#        'change', 'address_y', 'zip_y'],
#       dtype='object')

# %% [markdown]
# ### Suffixes

# %%
ward_census = wards.merge(census, on='ward', suffixes = ('_ward', '_cen'))
ward_census.head()
# Out:
#    ward                 alderman                       address_ward  zip_ward  \
# 0     1   "Proco ""Joe"" Moreno"          2058 NORTH WESTERN AVENUE     60647
# 1     2            Brian Hopkins         1400 NORTH  ASHLAND AVENUE     60622
# 2     3               Pat Dowell            5046 SOUTH STATE STREET     60609
# 3     4         William D. Burns   "435 EAST 35TH STREET 1ST FLOOR"     60616
# 4     5       Leslie A. Hairston              2325 EAST 71ST STREET     60649
#
#    pop_2000  pop_2010 change                               address_cen  \
# 0     52951     56149     6%               2765 WEST SAINT MARY STREET
# 1     54361     55805     3%                  WM WASTE MANAGEMENT 1500
# 2     40385     53039    31%                       17 EAST 38TH STREET
# 3     51953     54589     5%   31ST ST HARBOR BUILDING LAKEFRONT TRAIL
# 4     55302     51455    -7%   JACKSON PARK LAGOON SOUTH CORNELL DRIVE
#
#    zip_cen
# 0    60647
# 1    60622
# 2    60653
# 3    60653
# ...

# %%
ward_census.shape
# Out:
# (50, 9)

# %% [markdown]
# #### One to Many Example

# %%
licenses = pd.read_csv('')
