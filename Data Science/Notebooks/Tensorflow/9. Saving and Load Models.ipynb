# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist

# %%
(x_train,y_train), (x_test, y_test) = mnist.load_data()
x_train = x_train.reshape(-1,28*28).astype('float32')/255.0
x_test = x_test.reshape(-1,28*28).astype('float32')/255.0

# %%
model1 = keras.Sequential([
    layers.Dense(64, activation='relu'),
    layers.Dense(10)
])

model1.compile(
    loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer = keras.optimizers.Adam(),
    metrics=['accuracy']
)

model1.fit(x_train,y_train, batch_size=32, epochs=2)
model1.evaluate(x_test, y_test, batch_size=32)
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3134 - accuracy: 0.9113
# Epoch 2/2
# ...
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1260 - accuracy: 0.9625
# [0.12598353624343872, 0.9624999761581421]

# %%
model1.weights
# Out:
# [<tf.Variable 'dense/kernel:0' shape=(784, 64) dtype=float32, numpy=
#  array([[-0.067112  ,  0.01376896,  0.05445545, ..., -0.01477975,
#           0.033068  ,  0.05866886],
#         [ 0.03833344,  0.02708112,  0.00682823, ...,  0.08206908,
#           0.07255188, -0.06848165],
#         [-0.07388079,  0.01258139,  0.02194901, ..., -0.04066455,
#           0.01339019, -0.02393537],
#         ...,
#         [ 0.01494528,  0.05201863,  0.00731774, ...,  0.02207913,
#           0.03704965,  0.06047953],
#         [ 0.00807533, -0.05226543,  0.04899644, ...,  0.0405084 ,
#          -0.02017406,  0.00069335],
#         [-0.03801774,  0.06921136, -0.0399299 , ..., -0.0480295 ,
#          -0.00422291, -0.00424507]], dtype=float32)>,
#  <tf.Variable 'dense/bias:0' shape=(64,) dtype=float32, numpy=
#  array([ 0.03848978, -0.039519  ,  0.17196764,  0.11442306,  0.01971536,
#         -0.03270872,  0.07873797, -0.11157174,  0.02838576,  0.16522743,
# ...

# %%
# How to save and load model weights?
model1.save_weights('saved_model/')

# %%
model1.load_weights('saved_model/')

# %%
model1.fit(x_train,y_train, batch_size=32, epochs=2)
# Out:
# Epoch 1/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1084 - accuracy: 0.9675
# Epoch 2/2
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0855 - accuracy: 0.9743

# %%
# How to save and load entire model (Serializing model)?
# - Save weights
# - Model architecture
# - Training Configuration (model.compile())
# - Optimizer and states

model1.save('complete_saved_model/')
# Out:
# INFO:tensorflow:Assets written to: complete_saved_model/assets
